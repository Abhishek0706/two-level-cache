# %%
import matplotlib.pyplot as plt
plt.plot( [8, 16, 32, 64, 128, 256, 512],[83.9918, 85.0911, 86.0753, 86.6871, 86.9124, 86.9147, 86.9377], label='1')
plt.ylabel('Hit Ratio')
plt.xlabel('First Level Cache Size')
plt.plot([8, 16, 32, 64, 128, 256, 512],[85.275, 85.6476, 86.4065, 86.7905, 87.1125, 87.1194, 87.1194], label='2' )
plt.plot([8, 16, 32, 64, 128, 256, 512],[85.3992, 85.8224, 86.5353, 87.0895, 87.1194, 87.1194, 87.1194],label='4' )
plt.title('Hit Ratio of First Level Cache')
plt.legend()

plt.show()

# %%
plt.plot( [256, 512],[30.9787, 31.172],label='L1 = 128K')
plt.ylabel('Hit Ratio')
plt.xlabel('Second Level Cache Size')
plt.plot([128, 256, 512],[32.1299, 32.1472, 32.3372],label='L1 = 64K' )
plt.plot([64 ,128, 256, 512],[33.5425, 35.128, 35.1445, 35.3262],label='L1 = 32K' )
plt.plot([32 ,64, 128, 256, 512],[34.8141, 37.8528, 39.3953, 39.4108, 39.5959],label='L1 = 16K' )
plt.plot([32 ,64, 128, 256, 512],[39.1754, 42.0917, 43.557, 43.5713, 43.7437],label='L1 = 8K' )
plt.title('Cache Hit Ratios')
plt.legend()

plt.show()

# %%
plt.plot( [8, 16, 32],[42.0917, 37.8528, 33.5425],label='L2 = 64K')
plt.ylabel('Hit Ratio')
plt.xlabel('First Level Cache Size')
plt.plot([8, 16, 32, 64],[43.557, 39.3953, 35.128, 32.1299],label='L2 = 128K' )
plt.plot([8, 16 ,32,64 ,128],[43.5713, 39.4108, 35.1445, 32.1472, 30.9787],label='L2 = 256K' )
plt.plot([8, 16, 32, 64, 128],[43.7437, 39.5959, 35.3262, 32.3372, 31.172],label='L2 = 512K' )
plt.title('Effect of L1 size on L2 hit ratio')
plt.legend()

plt.show()

# %%
plt.plot( [32, 64, 128, 256, 512],[35.9776, 35.8243, 35.7177, 35.7166, 35.7034],label='L1 = 8K')
plt.ylabel('10^4 times cycle')
plt.xlabel('Second Level Cache Size')
plt.plot([32, 64, 128, 256, 512],[35.8428, 35.6961, 35.5917, 35.5906, 35.5774],label='L1 = 16K' )
plt.plot([64, 128, 256, 512],[35.5777, 35.4770, 35.4759, 35.4638],label='L1 = 32K' )
plt.plot([128, 256, 512],[35.4282, 35.4282, 35.4150],label='L1 = 64K' )
plt.plot([256, 512],[35.3903, 35.3782], label='L1 = 128K')
plt.title('Performance of Two-Level Caches')
plt.legend()

plt.show()

# %%
plt.plot( [8,16],[35.9776, 35.8428], label='L2 = 32K')
plt.ylabel('10^4 times cycle')
plt.xlabel('First Level Cache Size')
plt.plot([8, 16, 32],[35.8243, 35.6961, 35.5777],label='L2 = 64K' )
plt.plot([8 ,16 , 32, 64],[35.7177, 35.5917, 35.4770, 35.4282],label='L2 = 128K' )
plt.plot([8, 16, 32, 64, 128],[35.7166, 35.5906, 35.4759, 35.4271, 35.3909],label='L2 = 256K')
plt.plot([8, 16, 32, 64, 128, 256],[35.7034, 35.5774, 35.4638, 35.4150, 35.3782, 35.3778],label='L2 = 512K')
plt.title('Performance of Two-Level Caches')
plt.legend()
                                    
plt.show()

# %%
plt.plot( [128, 256, 512, 1024, 2048, 4096],[36.4756, 35.4741, 35.4591, 35.4231, 35.4231, 35.4231],label='L2 = 8K')
plt.ylabel('10^4 times cycle')
plt.xlabel('First Level Cache Size')
plt.plot([128, 256, 512, 1024, 2048, 4096],[35.4511, 35.4496, 35.4346, 35.3997, 35.3997, 35.3997],label='L2 = 16K' )
plt.plot([128, 256, 512, 1024, 2048, 4096],[35.4437, 35.4422, 35.4272, 35.3923, 35.3923, 35.3923],label='L2 = 32K' )
plt.plot([128, 256, 512, 1024, 2048, 4096],[35.4142, 35.4127, 35.3977, 35.3628, 35.3628, 35.3628],label='L2 = 64K')
plt.plot([128, 256, 512, 1024, 2048, 4096],[35.3914, 35.3899, 35.3749, 35.3400, 35.3400, 35.3400],label='L2 = 128K')
plt.title('Performance of Small L1 Cache')
plt.legend()

plt.show()

# %%
plt.plot( [2, 4, 6, 8, 10, 12, 14, 16],[39.2400, 40.4962, 41.7524, 43.0086, 44.2648, 45.5210, 46.7772, 48.0334],label='L1 = 8K, L2 = 128K, M = 30cycles')
plt.ylabel('10^4 times cycle')
plt.xlabel('Second Level Cache Access Time')
plt.plot([2, 4, 6, 8, 10, 12, 14, 16],[36.7250, 37.9812, 39.2374, 40.4936, 41.7498, 43.0060, 44.2622, 45.5184],label='L1 = 8K, L2 = 128K, M = 20cycles' )
plt.plot([2, 4 ,6, 8, 10, 12, 14, 16],[35.4675, 36.7237, 37.9799, 39.2361, 40.4923, 41.7485, 43.0047, 44.2609],label='L1 = 8K , L2 = 128K, M = 15cycles' )
plt.plot([2, 4, 6, 8, 10, 12, 14, 16],[36.6620, 37.8552, 39.0484, 40.2416, 41.4348, 42.6280, 43.8212, 45.0144],label='L1 = 16K, L2 = 128K, M = 20cycles')
plt.plot([2,4, 6, 8,10, 12],[35.4045, 36.5977, 37.7909, 38.9841, 40.1773, 41.3705],label='L1 = 16K, L2 = 128K, M = 15cycles')
plt.plot([2,4, 6, 8,10, 12, 14, 16],[36.6032, 37.7396, 38.8760, 40.0124, 41.1488, 42.2852, 43.4216, 44.5580],label='L1 = 32K, L2 = 128K, M = 20cycles')
plt.plot([2,4, 6, 8,10, 12],[35.3462, 36.4826, 37.6190, 38.7554, 39.8918, 41.0282],label= 'L1 = 32K, L2 = 128K, M = 15cycles')
plt.title('Execution Time vs. L2 Cache Access Time')
plt.legend()

plt.show()
